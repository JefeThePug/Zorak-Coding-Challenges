# %%
import numpy as np

from PIL import Image
from collections import deque

def in_thresh(target_color, pixel_color, t):
    return all(abs(int(pixel_color[i]) - int(target_color[i])) <= t for i in range(3))

def flood_fill(img, start, color, t):
    target_color = img[start].copy()
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    
    queue = deque([start])
    visited = set([start])
    
    while queue:
        y, x = queue.popleft()
        if (
            x in range(img.shape[1]) 
            and y in range(img.shape[0]) 
            and in_thresh(img[y, x], target_color, t)
        ):
            img[y, x] = color
            
            for dx, dy in directions:
                neighbor = (y + dy, x + dx)
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)


pixels = np.array(Image.open("startest.png").convert("RGB"))

shots = [
    (420, 115), (616, 616), (329, 128), (889, 699), (599, 843), 
    (524, 152), (923, 539), (636, 215), (215, 184), (269, 579), 
    (111, 513), (216, 241), (277, 112), (100, 450), (116, 171), 
    (865, 900), (825, 684), (649, 807), (796, 796), (141, 326), 
    (703, 869), (626, 643), (801, 712), (697, 665), (117, 418), 
    (642, 625), (878, 793), (902, 866), (806, 651), (716, 804), 
    (700, 886), (133, 133), (139, 44), (41, 337), (132, 55),
]
steps = {
    (255, 255, 255): (255, 255, 0), 
    (255, 255, 0): (0, 255, 255), 
    (0, 255, 255): (0, 255, 255),
}
threshold = 0

for shot in shots:
    for part in (shot, shot[::-1]):
        color = tuple(pixels[part])
        flood_fill(pixels, part, steps[color], threshold)

img = Image.fromarray(pixels)
img.save("result.png")

img
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000>

# %%
(8 * 400) + (6 * 200) - (35 * 100)
# Out:
# 900

# %%
6*200 - 35*100
# Out:
# -2300

# %%
2*200 - 4*100
# Out:
# 0

# %%
400 + 200 - 400
# Out:
# 200

# %%
import numpy as np

from PIL import Image
from collections import deque

def in_thresh(target_color, pixel_color, t):
    return all(abs(int(pixel_color[i]) - int(target_color[i])) <= t for i in range(3))

def flood_fill(img, start, color, t):
    target_color = img[start].copy()
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    
    queue = deque([start])
    visited = set([start])
    
    while queue:
        y, x = queue.popleft()
        if (
            x in range(img.shape[1]) 
            and y in range(img.shape[0]) 
            and in_thresh(img[y, x], target_color, t)
        ):
            img[y, x] = color
            
            for dx, dy in directions:
                neighbor = (y + dy, x + dx)
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)


pixels = np.array(Image.open("test.png").convert("RGB"))

shots = [(66, 147), (120, 123), (329, 181), (368, 339)]
steps = {
    (255, 255, 255): (255, 255, 0), 
    (255, 255, 0): (0, 255, 255), 
    (0, 255, 255): (0, 255, 255),
}
threshold = 250

for shot in shots:
    for part in (shot, shot[::-1]):
        color = tuple(pixels[part])
        flood_fill(pixels, part, steps[color], threshold)
        #pixels[part] = (255, 0, 0)

img = Image.fromarray(pixels)
img.save("testresult.png")

img
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
from collections import Counter
pat = [tuple(pixel) for pixel in pixels.reshape(-1, 3)]
c = Counter(pat)

# %%
8866/9092
# Out:
# 0.9751429828420589

# %%
from IPython.display import Markdown, display
from itertools import combinations, permutations

def r2h(rgb):
    r,g,b=rgb
    return "#" + '%02x%02x%02x' % (r,g,b)

def swatches(colors, sep=' ', width=6):
    display(Markdown(sep.join(
        f'<span style="color: {r2h(color)}"><span style="font-family: monospace">{v} {chr(9608)*width} {color}</span></span>'
        for color, v in colors
    )))
    
print("Yellows:", c[((255, 255, 0))])
swatches(c.most_common(), "<br>", 70)
# Out:
# Yellows: 28456
# <span style="color: #ffffff"><span style="font-family: monospace">109426 ██████████████████████████████████████████████████████████████████████ (255, 255, 255)</span></span><br><span style="color: #ffff00"><span style="font-family: monospace">28456 ██████████████████████████████████████████████████████████████████████ (255, 255, 0)</span></span><br><span style="color: #000000"><span style="font-family: monospace">8986 ██████████████████████████████████████████████████████████████████████ (0, 0, 0)</span></span><br><span style="color: #00ffff"><span style="font-family: monospace">8866 ██████████████████████████████████████████████████████████████████████ (0, 255, 255)</span></span><br><span style="color: #fbfbfb"><span style="font-family: monospace">193 ██████████████████████████████████████████████████████████████████████ (251, 251, 251)</span></span><br><span style="color: #fefefe"><span style="font-family: monospace">129 ██████████████████████████████████████████████████████████████████████ (254, 254, 254)</span></span><br><span style="color: #fdfdfd"><span style="font-family: monospace">111 ██████████████████████████████████████████████████████████████████████ (253, 253, 253)</span></span><br><span style="color: #fcfcfc"><span style="font-family: monospace">87 ██████████████████████████████████████████████████████████████████████ (252, 252, 252)</span></span><br><span style="color: #eeeeee"><span style="font-family: monospace">72 ██████████████████████████████████████████████████████████████████████ (238, 238, 238)</span></span><br><span style="color: #404040"><span style="font-family: monospace">72 ██████████████████████████████████████████████████████████████████████ (64, 64, 64)</span></span><br><span style="color: #f2f2f2"><span style="font-family: monospace">69 ██████████████████████████████████████████████████████████████████████ (242, 242, 242)</span></span><br><span style="color: #f7f7f7"><span style="font-family: monospace">68 ██████████████████████████████████████████████████████████████████████ (247, 247, 247)</span></span><br><span style="color: #f8f8f8"><span style="font-family: monospace">68 ██████████████████████████████████████████████████████████████████████ (248, 248, 248)</span></span><br><span style="color: #b4b4b4"><span style="font-family: monospace">64 ██████████████████████████████████████████████████████████████████████ (180, 180, 180)</span></span><br><span style="color: #f9f9f9"><span style="font-family: monospace">63 ██████████████████████████████████████████████████████████████████████ (249, 249, 249)</span></span><br><span style="color: #979797"><span style="font-family: monospace">63 ██████████████████████████████████████████████████████████████████████ (151, 151, 151)</span></span><br><span style="color: #9f9f9f"><span style="font-family: monospace">59 ██████████████████████████████████████████████████████████████████████ (159, 159, 159)</span></span><br><span style="color: #efefef"><span style="font-family: monospace">58 ██████████████████████████████████████████████████████████████████████ (239, 239, 239)</span></span><br><span style="color: #757575"><span style="font-family: monospace">55 ██████████████████████████████████████████████████████████████████████ (117, 117, 117)</span></span><br><span style="color: #bbbbbb"><span style="font-family: monospace">54 ██████████████████████████████████████████████████████████████████████ (187, 187, 187)</span></span><br><span style="color: #f3f3f3"><span style="font-family: monospace">53 ██████████████████████████████████████████████████████████████████████ (243, 243, 243)</span></span><br><span style="color: #e5e5e5"><span style="font-family: monospace">51 ██████████████████████████████████████████████████████████████████████ (229, 229, 229)</span></span><br><span style="color: #868686"><span style="font-family: monospace">49 ██████████████████████████████████████████████████████████████████████ (134, 134, 134)</span></span><br><span style="color:  ...

# %%
import numpy as np

from PIL import Image
from collections import deque

def in_thresh(target_color, pixel_color, t):
    return all(abs(int(pixel_color[i]) - int(target_color[i])) <= t for i in range(3))

def flood_fill(img, start, color, t):
    target_color = img[start].copy()
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    
    queue = deque([start])
    visited = set([start])
    
    while queue:
        y, x = queue.popleft()
        if (
            x in range(img.shape[1]) 
            and y in range(img.shape[0]) 
            and in_thresh(img[y, x], target_color, t)
        ):
            img[y, x] = color
            
            for dx, dy in directions:
                neighbor = (y + dy, x + dx)
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)


pixels = np.array(Image.open("pxArt.png").convert("RGB"))
#pixels = np.array(Image.open("startest.png").convert("RGB"))

shots = [(100, 100)]

steps = {
    (255, 255, 255): (255, 255, 0), 
    (255, 255, 0): (0, 255, 255), 
    (0, 255, 255): (0, 255, 255),
}
threshold = 250

for shot in shots:
    for part in (shot, shot[::-1]):
        color = tuple(pixels[part])
        flood_fill(pixels, part, (255, 0, 0), threshold)
        #pixels[part] = (255, 0, 0)

img = Image.fromarray(pixels)
#img.save("testresult.png")

img
# Out:
# <PIL.Image.Image image mode=RGB size=788x792>

# %%
img = np.array(Image.open("pxArt2.png").convert("RGB"))
grayscale_pixels = np.mean(img, axis=2)
black_mask = grayscale_pixels <= threshold
ascii_pixels = np.where(black_mask, '#', ' ')
np.savetxt('look.txt', ascii_pixels, delimiter='', fmt='%s')

# rev_mask = ascii_pixels == "#"
# black_pixel = np.array([0, 0, 0], dtype=img.dtype)
# white_pixel = np.array([255, 255, 255], dtype=img.dtype)
# new_img = np.where(rev_mask[..., None], black_pixel, white_pixel)
# img = Image.fromarray(new_img)

# img.save("pxArt2.png")

# %%
pixels = np.array(Image.open("pxArt2.png").convert("RGB"))

def flood_fill(img, start, color, t):
    target_color = img[start].copy()
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    
    queue = deque([start])
    visited = set([start])
    
    while queue:
        y, x = queue.popleft()
        if (
            x in range(img.shape[1]) 
            and y in range(img.shape[0]) 
            and in_thresh(img[y, x], target_color, t)
        ):
            img[y, x] = color
            
            for dx, dy in directions:
                neighbor = (y + dy, x + dx)
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)

shots = [(0, 0)]

steps = {
    (255, 255, 255): (255, 255, 0), 
    (255, 255, 0): (0, 255, 255), 
    (0, 255, 255): (0, 255, 255),
}
threshold = 250

for shot in shots:
    for part in (shot, shot[::-1]):
        color = tuple(pixels[part])
        flood_fill(pixels, part, (255, 0, 0), threshold)
        #pixels[part] = (255, 0, 0)
        
count = np.sum(np.all(pixels == np.array([255, 0, 0]), axis=-1))
img = Image.fromarray(pixels)
#img.save("pxArt2.png")
print(count)
img
# Out:
# 13119
# <PIL.Image.Image image mode=RGB size=197x198>

# %%
def flood_fill(img, start, color, t):
    target_color = img[start].copy()
    directions = [(-1, 0), (1, 0), (0, -1), (0, 1)]
    
    queue = deque([start])
    visited = set([start])
    
    while queue:
        y, x = queue.popleft()
        if (
            x in range(img.shape[1]) 
            and y in range(img.shape[0]) 
            and img[y, x] == target_color
        ):
            img[y, x] = color
            
            for dx, dy in directions:
                neighbor = (y + dy, x + dx)
                if neighbor not in visited:
                    queue.append(neighbor)
                    visited.add(neighbor)

                    
with open("look.txt") as f:
    img = np.array([list(line.strip("\n")) for line in f.readlines()], dtype=str)

flood_fill(img, (0,0), "@", 0)
np.count_nonzero(img == "@")
# Out:
# 13119
