# %% [markdown]
# # BUILDING

# %% [raw]
# Nebula Labyrinth
#
# Electromagnetic Storms

# %% [markdown]
# # SOLVING

# %%
def dfs(nodes, connections, start, end):
    visited = {node: False for node in nodes}
    stack = [start]
    parents = {start: None}

    while stack:
        current_node = stack.pop()
        visited[current_node] = True
        if current_node == end:
            return reconstruct_path(parents, start, end)
        for neighbor in reversed(connections[current_node]):
            if not visited[neighbor]:
                stack.append(neighbor)
                parents[neighbor] = current_node
    return None

def reconstruct_path(parents, start, end):
    path = [end]
    current_node = end
    while current_node != start:
        current_node = parents[current_node]
        path.append(current_node)
    return path[::-1]


connections = dict()

with open("nodes_a.txt") as f:
    for line in f:
        item, cons = line.strip().split(":")
        connections[item] = cons.split(",")
        
nodes = [f"{n}" for n in connections]

start_node = "63"
end_node = "3659"

path = dfs(nodes, connections, start_node, end_node)
if path:
    print(f"Shortest path from {start_node} to {end_node}: (Size - {len(path)})\n{path}")
else:
    print("No path exists from", start_node, "to", end_node)
# Out:
# Shortest path from 63 to 3659: (Size - 289)
# ...

# %%
print(len(path))
arr = [("🟨" if str(x) in path else "⬜") if str(x) in nodes else "🟫" for x in range(1, 3722)]
grid = np.array(arr).reshape((61,61))

np.savetxt("grid2partA.txt", grid, fmt='%s', delimiter='')

arr = [" " if str(x) in nodes else "#" for x in range(1, 3722)]
grid = np.array(arr).reshape((61,61))

np.savetxt("gridpartA.txt", grid, fmt='%s', delimiter=',')
# Out:
# 289

# %% [markdown]
# # BUILDING

# %%
paths = {
    101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 120, 
    121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 140, 
    142, 143, 144, 145, 146, 148, 149, 151, 152, 154, 155, 156, 158, 160, 161, 162, 163, 164, 165, 
    166, 167, 168, 170, 171, 172, 174, 176, 178, 179, 180, 182, 183, 184, 185, 186, 188, 189, 190, 
    191, 192, 193, 194, 195, 197, 198, 199, 210, 216, 220, 230, 236, 240, 242, 246, 248, 252, 254, 
    256, 258, 260, 262, 268, 270, 272, 274, 276, 280, 282, 292, 294, 297, 299, 302, 303, 304, 306, 
    308, 309, 310, 312, 314, 316, 317, 318, 320, 322, 323, 324, 326, 328, 329, 330, 332, 334, 336, 
    337, 338, 340, 342, 343, 344, 346, 347, 348, 349, 350, 352, 353, 354, 356, 357, 358, 359, 360, 
    362, 364, 366, 368, 370, 372, 373, 374, 375, 376, 378, 379, 380, 382, 384, 386, 387, 388, 389, 
    390, 391, 392, 394, 395, 397, 399, 404, 406, 410, 412, 414, 416, 420, 424, 426, 430, 432, 434, 
    436, 440, 441, 442, 450, 452, 462, 464, 466, 468, 472, 480, 482, 484, 492, 494, 497, 499, 502, 
    503, 504, 506, 508, 510, 512, 513, 514, 516, 518, 519, 520, 522, 523, 524, 526, 528, 530, 532, 
    533, 534, 536, 538, 539, 540, 542, 543, 544, 545, 546, 548, 550, 552, 554, 555, 556, 558, 559, 
    560, 562, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574,
neighbors_dict = {}

for i in range(grid.shape[0]):
    for j in range(grid.shape[1]):
        item = grid[i, j]
        if item!= "XXXX":
            neighbors = []
            # Check above
            if i > 0 and grid[i-1, j]!= "XXXX":
                neighbors.append(grid[i-1, j].lstrip("0"))
            # Check left
            if j > 0 and grid[i, j-1]!= "XXXX":
                neighbors.append(grid[i, j-1].lstrip("0"))
            # Check right
            if j < grid.shape[1] - 1 and grid[i, j+1]!= "XXXX":
                neighbors.append(grid[i, j+1].lstrip("0"))
            # Check below
            if i < grid.shape[0] - 1 and grid[i+1, j]!= "XXXX":
                neighbors.append(grid[i+1, j].lstrip("0"))
            # Add the item and its neighbors to the dictionary
            neighbors_dict[item.lstrip("0")] = ",".join(neighbors)

# %%
portals = """197 
 1209 
 1573 
 1733 
 2127 
 3168 
 3176 
 3184 
 3252 
 3754 
 3758 
 3764 
 3772 
 3780 
 3787 
 6167 
 7530 
 8170 
 9711  """
reverse_portals = """297 
 1110 
 1571 
 3164 
 3172 
 3179 
 3188 
 3355 
 3650 
 3760 
 3768 
 3774 
 3782 
 5327 
 5967 
 7495 
 8358 
 8497 
 9184 
 9405 
 9695"""

portals = [i.strip() for i in portals.split("\n")]
reverse_portals = [i.strip() for i in reverse_portals.split("\n")]
outputline = ",".join(portals)


for item in reverse_portals:
    neighbors_dict[item] = outputline

# %%
with open("nodes.txt", "w") as f:
    for k, val in neighbors_dict.items():
        if k == "297":
            print(val)
        f.write(f"{k.lstrip('0')}:{val}\n")
# Out:
# 197,1209,1573,1733,2127,3168,3176,3184,3252,3754,3758,3764,3772,3780,3787,6167,7530,8170,9711

# %%
from collections import deque

def bfs(nodes, connections, start, end):
    visited = {node: False for node in nodes}
    queue = deque()
    queue.append(start)
    visited[start] = True
    parents = {start: None}

    while queue:
        current_node = queue.popleft()
        if current_node == end:
            return reconstruct_path(parents, start, end)
        for neighbor in connections[current_node]:
            if not visited[neighbor]:
                queue.append(neighbor)
                visited[neighbor] = True
                parents[neighbor] = current_node
    return visited

def reconstruct_path(parents, start, end):
    path = [end]
    current_node = end
    while current_node != start:
        current_node = parents[current_node]
        path.append(current_node)
    return path[::-1]


connections = dict()

with open("nodes.txt") as f:
    for line in f:
        item, cons = line.strip().split(":")
        connections[item] = cons.split(",")
        
nodes = [f"{n}" for n in connections]

start_node = "101"
end_node = "9900"

path = bfs(nodes, connections, start_node, end_node)
if path:
    print("Shortest path from", start_node, "to", end_node, ":", path)
else:
    print("No path exists from", start_node, "to", end_node)
# Out:
# Shortest path from 101 to 9900 : ['101', '102', '103', '104', '105', '106', '107', '108', '109', '110', '210', '310', '410', '510', '610', '710', '810', '910', '909', '908', '1008', '1007', '1107', '1207', '1206', '1306', '1406', '1407', '1507', '1607', '1606', '1706', '1806', '1807', '1907', '2007', '2107', '2207', '2307', '2407', '2507', '2607', '2606', '2706', '2806', '2906', '3006', '3005', '3004', '3104', '3204', '3203', '3202', '3302', '3402', '3403', '3404', '3504', '3604', '3605', '3606', '3607', '3707', '3807', '3907', '4007', '4006', '4005', '4004', '4003', '4002', '4102', '4202', '4302', '4402', '4502', '4602', '4702', '4802', '4902', '5002', '5003', '5004', '5104', '5204', '5205', '5206', '5207', '5307', '5407', '5507', '5607', '5606', '5706', '5806', '5805', '5804', '5904', '6004', '6104', '6204', '6304', '6404', '6405', '6406', '6407', '6507', '6607', '6608', '6609', '6610', '6710', '6810', '6811', '6812', '6912', '7012', '7112', '7212', '7312', '7412', '7512', '7612', 
# ...

# %%
print(len(path))
arr = [("🟨" if str(x) in path else "⬜") if str(x) in nodes else "🟫" for x in range(1, 10001)]
grid = np.array(arr).reshape((100,100))

np.savetxt("grid2.txt", grid, fmt='%s', delimiter='')

arr = [" " if str(x) in nodes else "#" for x in range(1, 10001)]
grid = np.array(arr).reshape((100,100))

np.savetxt("grid.txt", grid, fmt='%s', delimiter=',')
# Out:
# 424

# %% [markdown]
# # SOLVING

# %%
from collections import deque

def bfs(nodes, connections, start, end):
    visited = {node: False for node in nodes}
    queue = deque()
    queue.append(start)
    visited[start] = True
    parents = {start: None}

    while queue:
        current_node = queue.popleft()
        if current_node == end:
            return reconstruct_path(parents, start, end)
        for neighbor in connections[current_node]:
            if not visited[neighbor]:
                queue.append(neighbor)
                visited[neighbor] = True
                parents[neighbor] = current_node
    return visited

def reconstruct_path(parents, start, end):
    path = [end]
    current_node = end
    while current_node != start:
        current_node = parents[current_node]
        path.append(current_node)
    return path[::-1]


connections = dict()

with open("nodes.txt") as f:
    start_node, end_node = next(f).split(",")

    for line in f:
        item, cons = line.strip().split(":")
        connections[item] = cons.split(",")
        
nodes = [f"{n}" for n in connections]


path = bfs(nodes, connections, start_node, end_node)
if path:
    print(f"Shortest path from {start_node} to {end_node}: (Size - {len(path)})\n{path}")
else:
    print("No path exists from", start_node, "to", end_node)
# Out:
# Shortest path from 101 to 9900
# : (Size - 4853)
# ...

# %% [markdown]
# # Wrong
# DFS instead of BFS

# %%
arr = [("🟥" if str(x) in pathb else "⬜") if str(x) in nodes else "🟫" for x in range(1, 10001)]
grid = np.array(arr).reshape((100,100))

np.savetxt("gridwrong.txt", grid, fmt='%s', delimiter='')

# %%
len(pathb)
# Out:
# 1557

# %%
import numpy as np
from PIL import Image

hidden = """3048	3049	3050	3051	3052	3053	3054	3055	3056	3057	3058	3059	3060	3061	3062	3063	3064	3065	3066	3067	3068	3069	3070	3071	3072	3073	3074	3075	3076	3077	3078	3079	3080	3081	3082	3083	3084	3085	3086	3087	3088	3089	3090
3148	3149	3150	3151	3152	3153	3154	3155	3156	3157	3158	3159	3160	3161	3162	3163	3164	3165	3166	3167	3168	3169	3170	3171	3172	3173	3174	3175	3176	3177	3178	3179	3180	3181	3182	3183	3184	3185	3186	3187	3188	3189	3190
3248	3249	3250	3251	3252	3253	3254	3255	3256	3257	3258	3259	3260	3261	3262	3263	3264	3265	3266	3267	3268	3269	3270	3271	3272	3273	3274	3275	3276	3277	3278	3279	3280	3281	3282	3283	3284	3285	3286	3287	3288	3289	3290
3348	3349	3350	3351	3352	3353	3354	3355	3356	3357	3358	3359	3360	3361	3362	3363	3364	3365	3366	3367	3368	3369	3370	3371	3372	3373	3374	3375	3376	3377	3378	3379	3380	3381	3382	3383	3384	3385	3386	3387	3388	3389	3390
3448	3449	3450	3451	3452	3453	3454	3455	3456	3457	3458	3459	3460	3461	3462	3463	3464	3465	3466	3467	3468	3469	3470	3471	3472	3473	3474	3475	3476	3477	3478	3479	3480	3481	3482	3483	3484	3485	3486	3487	3488	3489	3490
3548	3549	3550	3551	3552	3553	3554	3555	3556	3557	3558	3559	3560	3561	3562	3563	3564	3565	3566	3567	3568	3569	3570	3571	3572	3573	3574	3575	3576	3577	3578	3579	3580	3581	3582	3583	3584	3585	3586	3587	3588	3589	3590
3648	3649	3650	3651	3652	3653	3654	3655	3656	3657	3658	3659	3660	3661	3662	3663	3664	3665	3666	3667	3668	3669	3670	3671	3672	3673	3674	3675	3676	3677	3678	3679	3680	3681	3682	3683	3684	3685	3686	3687	3688	3689	3690
3748	3749	3750	3751	3752	3753	3754	3755	3756	3757	3758	3759	3760	3761	3762	3763	3764	3765	3766	3767	3768	3769	3770	3771	3772	3773	3774	3775	3776	3777	3778	3779	3780	3781	3782	3783	3784	3785	3786	3787	3788	3789	3790
3848	3849	3850	3851	3852	3853	3854	3855	3856	3857	3858	3859	3860	3861	3862	3863	3864	3865	3866	3867	3868	3869	3870	3871	3872	3873	3874	3875	3876	3877	3878	3879	3880	3881	3882	3883	3884	3885	3886	3887	3888	3889	3890""".split()

arr = [(255,255,255) if f"{x}" in nodes else (0,0,0) for x in range(1, 10001)]
grid = np.array(arr).reshape((100, 100, 3))

grid_copy = grid.copy()

for p in portals:
    x, y = divmod(int(p)-1, 100)
    grid_copy[x, y, 0] = 227
    grid_copy[x, y, 1] = 66
    grid_copy[x, y, 2] = 245
    
for p in reverse_portals:
    x, y = divmod(int(p)-1, 100)
    grid_copy[x, y, 0] = 66
    grid_copy[x, y, 1] = 245
    grid_copy[x, y, 2] = 179
    
for p in hidden:
    x, y = divmod(int(p)-1, 100)
    grid_copy[x, y, 0] = 0
    grid_copy[x, y, 1] = 0
    grid_copy[x, y, 2] = 0
    

for xi, p in enumerate(path):
    x, y = divmod(int(p)-1, 100)
    
    grid_copy[x, y, 0] = 0
    grid_copy[x, y, 1] = 140
    grid_copy[x, y, 2] = 0
    
    enlarged_grid = np.kron(grid_copy, np.ones((8, 8, 1), dtype=int))
    
    pixel_grid = enlarged_grid.astype(np.uint8)

    img = Image.fromarray(pixel_grid)
    n = xi + 1 + (10 * (xi > 307))
    
    img.save(f"gifs/grid{n}.png")

# %%
from PIL import Image
import glob

image_files = sorted(glob.glob("gifs/grid*.png"), key=lambda x: int(x.split("grid")[1].split(".")[0]))
print(len(image_files))

images = []
for image_file in image_files:
    with Image.open(image_file) as img:
        images.append(img.copy())

images[0].save('path_animation.gif', save_all=True, append_images=images[1:], duration=0.005, loop=None)
# Out:
# 434
